# %%
empty_tuple = ()
print(empty_tuple)
print( type(empty_tuple) )
# Out:
# ()
# <class 'tuple'>

# %%
t1 = (1,)
print( type(t1) )
# Out:
# <class 'tuple'>

# %%
t1 = (1,2.2,False,"vishal")
print(t1)
# Out:
# (1, 2.2, False, 'vishal')

# %%
print(t1[0])
print( t1 [ len(t1) - 1 ] )
# Out:
# 1
# vishal

# %%
l1 = list(t1)
print(l1)
# Out:
# [1, 2.2, False, 'vishal']

# %%
l1[0] = 2
print(l1[0])
# Out:
# 2

# %%
del t1

# %%
t1 = (1,2.2,False,"vishal")
print(t1)
# Out:
# (1, 2.2, False, 'vishal')

# %%
t1 = (1,2,3)
t2 = (4,5)
t3 = t1 + t2
print(t3)
# Out:
# (1, 2, 3, 4, 5)

# %%
values = (10,20,30,40,50)
print( len(values) )
# Out:
# 5

# %%
print( values.count(20) )
# Out:
# 1

# %%
print( values.index(10) )
# Out:
# 0

# %%
t = (1,2,3)
print( t*3 )
# Out:
# (1, 2, 3, 1, 2, 3, 1, 2, 3)

# %%
print( 30 in values )
# Out:
# True

# %%
print( max(values) )
print( min(values) )
# Out:
# 50
# 10

# %%
print( sum(values) )
# Out:
# 150

# %%
values = (4,2,5,1)
res = sorted(values)
print(res)
# Out:
# [1, 2, 4, 5]

# %%
text = "vishal"
t1 = tuple(text)
print(t1)
# Out:
# ('v', 'i', 's', 'h', 'a', 'l')

# %%
for i in t1:
  print(i,end="")
# Out:
# vishal

# %%
st = ("vishal",19,"betch")
name = st[0]
age = st[1]
course = st[2]
print(name,age,course)
# Out:
# vishal 19 betch

# %%
name,age,course = st
print(name,age,course)
# Out:
# vishal 19 betch

# %%
t = ( (1,3) , ("vishal","sharma") )
print(t)
# Out:
# ((1, 3), ('vishal', 'sharma'))

# %%
print( t[0] )
# Out:
# (1, 3)

# %%
print( t[1][1] )
# Out:
# sharma

# %%
t1 = (10,20)
t2 = (10,20,40)
print( t1 == t2 )
# Out:
# False

# %%
print( t2 > t1 )
# Out:
# True

# %%
for i in range(0, len(t1) ,1):
  print(t1[i])
# Out:
# 10
# 20

# %%
for i,val in enumerate(t1):
  print(i,val)
# Out:
# 0 10
# 1 20

# %%
cities = {"delhi","mathura","agra","agra"}
print(cities)
# Out:
# {'mathura', 'delhi', 'agra'}

# %%
cities.add("mumabi")

# %%
print(cities)
# Out:
# {'mathura', 'delhi', 'mumabi', 'agra'}

# %%
print(cities)
# Out:
# {'m', 'i', 'a', 's', 'agra', 'x', 'p', 'mathura', 'r', 'e', 'o', 'delhi', 'c', 'mumabi'}

# %%
print(cities)
# Out:
# {'m', 'i', 'a', 's', 'x', 'p', 'mathura', 'r', 'e', 'o', 'delhi', 'c', 'mumabi'}

# %%
cities.discard("agra")
print(cities)
# Out:
# {'m', 'i', 'a', 's', 'x', 'p', 'mathura', 'r', 'e', 'o', 'delhi', 'c', 'mumabi'}

# %%
cites.clear()
cities.clear()

# %%
print(cities)
# Out:
# set()

# %%
a = {"delhi","agra","mathura"}
b = {"Agra","mathura","nyc"}
print( a|b )
# Out:
# {'nyc', 'mathura', 'Agra', 'agra', 'delhi'}

# %%
print( a & b )
# Out:
# {'mathura'}

# %%
print( a - b )
# Out:
# {'agra', 'delhi'}

# %%
print( b - a )
# Out:
# {'nyc', 'Agra'}

# %%
student = {
    "name": "Rahul",
    "age": 20,
    "course": "Python",
    "marks": 85
}

# %%
print(student["name"])
print(student.get("age"))
# Out:
# Rahul
# 20

# %%
student["city"] = "Delhi"

# %%
student["marks"] = 90

# %%
print(student)
# Out:
# {'name': 'Rahul', 'age': 20, 'course': 'Python', 'marks': 90, 'city': 'Delhi'}

# %%
student.update({
    "age": 21,
    "course": "Data Science"
})

# %%
print(student)
# Out:
# {'name': 'Rahul', 'age': 21, 'course': 'Data Science', 'marks': 90, 'city': 'Delhi'}

# %%
del student["city"]

# %%
print(student)
# Out:
# {'name': 'Rahul', 'age': 21, 'course': 'Data Science', 'marks': 90}

# %%
student.clear()

# %%
print(student)
# Out:
# {}

# %%
student = {
    "name": "Rahul",
    "age": 20,
    "course": "Python",
    "marks": 85
}

# %%
print( student.values() )
# Out:
# dict_values(['Rahul', 20, 'Python', 85])

# %%
print( student.items() )
# Out:
# dict_items([('name', 'Rahul'), ('age', 20), ('course', 'Python'), ('marks', 85)])

# %%
for key,value in student.items():
  print(value,key)
# Out:
# Rahul name
# 20 age
# Python course
# 85 marks
